# %%
import pandas as pd
df = pd.read_csv('sales_dataset.csv')
df.head()
# Out:
#    index       Date    Year     Month  Customer Age Customer Gender  \
# 0      0  2/19/2016  2016.0  February          29.0               F
# 1      1  2/20/2016  2016.0  February          29.0               F
# 2      2  2/27/2016  2016.0  February          29.0               F
# 3      3  3/12/2016  2016.0     March          29.0               F
# 4      4  3/12/2016  2016.0     March          29.0               F
#
#          Country       State Product Category     Sub Category  Quantity  \
# 0  United States  Washington      Accessories  Tires and Tubes       1.0
# 1  United States  Washington         Clothing           Gloves       2.0
# 2  United States  Washington      Accessories  Tires and Tubes       3.0
# 3  United States  Washington      Accessories  Tires and Tubes       2.0
# 4  United States  Washington      Accessories  Tires and Tubes       3.0
#
#    Unit Cost  Unit Price   Cost  Revenue  Column1
# 0      80.00  109.000000   80.0    109.0      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34867 entries, 0 to 34866
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             34867 non-null  int64
#  1   Date              34866 non-null  object
#  2   Year              34866 non-null  float64
#  3   Month             34866 non-null  object
#  4   Customer Age      34866 non-null  float64
#  5   Customer Gender   34866 non-null  object
#  6   Country           34866 non-null  object
#  7   State             34866 non-null  object
#  8   Product Category  34866 non-null  object
#  9   Sub Category      34866 non-null  object
#  10  Quantity          34866 non-null  float64
#  11  Unit Cost         34866 non-null  float64
#  12  Unit Price        34866 non-null  float64
#  13  Cost              34866 non-null  float64
#  14  Revenue           34867 non-null  float64
#  15  Column1           2574 non-null   float64
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 34862    False
# 34863    False
# 34864    False
# 34865    False
# 34866    False
# Length: 34867, dtype: bool

# %%
df.drop_duplicates()
# Out:
#        index       Date    Year     Month  Customer Age Customer Gender  \
# 0          0  2/19/2016  2016.0  February          29.0               F
# 1          1  2/20/2016  2016.0  February          29.0               F
# 2          2  2/27/2016  2016.0  February          29.0               F
# 3          3  3/12/2016  2016.0     March          29.0               F
# 4          4  3/12/2016  2016.0     March          29.0               F
# ...      ...        ...     ...       ...           ...             ...
# 34862  34862   2/7/2016  2016.0  February          38.0               M
# 34863  34863  3/13/2015  2015.0     March          38.0               M
# 34864  34864   4/5/2015  2015.0     April          38.0               M
# 34865  34865  8/30/2015  2015.0    August          38.0               M
# 34866  34866        NaN     NaN       NaN           NaN             NaN
#
#              Country           State Product Category     Sub Category  \
# ...

# %%
df['Revenue'].unique()
# Out:
# array([ 109.      ,   57.      ,   15.      , ..., 1748.      ,
#        1971.      ,  641.532095])

# %%
df.drop(columns=['Column1'])
# Out:
#        index       Date    Year     Month  Customer Age Customer Gender  \
# 0          0  2/19/2016  2016.0  February          29.0               F
# 1          1  2/20/2016  2016.0  February          29.0               F
# 2          2  2/27/2016  2016.0  February          29.0               F
# 3          3  3/12/2016  2016.0     March          29.0               F
# 4          4  3/12/2016  2016.0     March          29.0               F
# ...      ...        ...     ...       ...           ...             ...
# 34862  34862   2/7/2016  2016.0  February          38.0               M
# 34863  34863  3/13/2015  2015.0     March          38.0               M
# 34864  34864   4/5/2015  2015.0     April          38.0               M
# 34865  34865  8/30/2015  2015.0    August          38.0               M
# 34866  34866        NaN     NaN       NaN           NaN             NaN
#
#              Country           State Product Category     Sub Category  \
# ...

# %%
df.rename(columns={'Unit Price': 'Unit Per Price'}, inplace=True)

# %%
 df.reindex()
# Out:
#        index       Date    Year     Month  Customer Age Customer Gender  \
# 0          0  2/19/2016  2016.0  February          29.0               F
# 1          1  2/20/2016  2016.0  February          29.0               F
# 2          2  2/27/2016  2016.0  February          29.0               F
# 3          3  3/12/2016  2016.0     March          29.0               F
# 4          4  3/12/2016  2016.0     March          29.0               F
# ...      ...        ...     ...       ...           ...             ...
# 34862  34862   2/7/2016  2016.0  February          38.0               M
# 34863  34863  3/13/2015  2015.0     March          38.0               M
# 34864  34864   4/5/2015  2015.0     April          38.0               M
# 34865  34865  8/30/2015  2015.0    August          38.0               M
# 34866  34866        NaN     NaN       NaN           NaN             NaN
#
#              Country           State Product Category     Sub Category  \
# ...

# %%
df.isna().sum()
# Out:
# index                   0
# Date                    1
# Year                    1
# Month                   1
# Customer Age            1
# Customer Gender         1
# Country                 1
# State                   1
# Product Category        1
# Sub Category            1
# Quantity                1
# Unit Cost               1
# Unit Per Price          1
# Cost                    1
# Revenue                 0
# Column1             32293
# dtype: int64

# %%
df.dropna()
# Out:
#       index       Date    Year     Month  Customer Age Customer Gender  \
# 312     312  1/11/2016  2016.0   January          40.0               M
# 313     313  1/11/2016  2016.0   January          40.0               M
# 314     314  1/18/2016  2016.0   January          40.0               M
# 315     315  1/18/2016  2016.0   January          40.0               M
# 316     316  1/18/2016  2016.0   January          40.0               M
# ...     ...        ...     ...       ...           ...             ...
# 2881   2881   1/5/2016  2016.0   January          28.0               M
# 2882   2882   1/7/2016  2016.0   January          28.0               M
# 2883   2883  2/20/2016  2016.0  February          28.0               M
# 2884   2884  2/24/2016  2016.0  February          28.0               M
# 2935   2935  2/19/2016  2016.0  February          52.0               M
#
#              Country           State Product Category       Sub Category  \
# ...

# %%
df.fillna(0, inplace=True)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='constant', fill_value=0)

# %%
df = pd.read_csv('sales_dataset.csv')

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Year', 'Month', 'Customer Age', 'Customer Gender',
#        'Country', 'State', 'Product Category', 'Sub Category', 'Quantity',
#        'Unit Cost', 'Unit Price', 'Cost', 'Revenue', 'Column1'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include=['number']).columns
df[num_cols] = imputer.fit_transform(df[num_cols])

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Cost'] = pd.to_numeric(df['Cost'])

# %%
df['Customer Age'] = pd.to_numeric(df['Customer Age'], errors='coerce')

# %%
df['Customer Age'] = df['Customer Age'].astype('Int64')

# %%
df['Country'] = df['Country'].str.replace('USA', 'United States')

# %%
df['Country'] = df['Country'].str.lower()

# %%
df.head()
# Out:
#    index       Date    Year     Month  Customer Age Customer Gender  \
# 0    0.0 2016-02-19  2016.0  February            29               F
# 1    1.0 2016-02-20  2016.0  February            29               F
# 2    2.0 2016-02-27  2016.0  February            29               F
# 3    3.0 2016-03-12  2016.0     March            29               F
# 4    4.0 2016-03-12  2016.0     March            29               F
#
#          Country       State Product Category     Sub Category  Quantity  \
# 0  united states  Washington      Accessories  Tires and Tubes       1.0
# 1  united states  Washington         Clothing           Gloves       2.0
# 2  united states  Washington      Accessories  Tires and Tubes       3.0
# 3  united states  Washington      Accessories  Tires and Tubes       2.0
# 4  united states  Washington      Accessories  Tires and Tubes       3.0
#
#    Unit Cost  Unit Price   Cost  Revenue  Column1
# 0      80.00  109.000000   80.0    109.0      0.0
# ...

# %%
df['Country'].str.strip()
# Out:
# 0        united states
# 1        united states
# 2        united states
# 3        united states
# 4        united states
#              ...
# 34862           france
# 34863           france
# 34864           france
# 34865           france
# 34866              NaN
# Name: Country, Length: 34867, dtype: object

# %%
np.where(df['Revenue'] > 1000, 'High', 'Low')
# Out:
# array(['Low', 'Low', 'Low', ..., 'High', 'High', 'Low'], dtype='<U4')

# %%
df['Country'].replace('usa', 'united states')
# Out:
# 0        united states
# 1        united states
# 2        united states
# 3        united states
# 4        united states
#              ...
# 34862           france
# 34863           france
# 34864           france
# 34865           france
# 34866              NaN
# Name: Country, Length: 34867, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34867 entries, 0 to 34866
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             34867 non-null  float64
#  1   Date              34866 non-null  datetime64[ns]
#  2   Year              34867 non-null  float64
#  3   Month             34866 non-null  object
#  4   Customer Age      34867 non-null  Int64
#  5   Customer Gender   34866 non-null  object
#  6   Country           34866 non-null  object
#  7   State             34866 non-null  object
#  8   Product Category  34866 non-null  object
#  9   Sub Category      34866 non-null  object
#  10  Quantity          34867 non-null  float64
#  11  Unit Cost         34867 non-null  float64
#  12  Unit Price        34867 non-null  float64
#  13  Cost              34867 non-null  float64
#  14  Revenue           34867 non-null  float64
#  15  Column1           34867 non-null  float64
# ...

# %%
df.head()
# Out:
#    index       Date    Year     Month  Customer Age Customer Gender  \
# 0    0.0 2016-02-19  2016.0  February            29               F
# 1    1.0 2016-02-20  2016.0  February            29               F
# 2    2.0 2016-02-27  2016.0  February            29               F
# 3    3.0 2016-03-12  2016.0     March            29               F
# 4    4.0 2016-03-12  2016.0     March            29               F
#
#          Country       State Product Category     Sub Category  Quantity  \
# 0  united states  Washington      Accessories  Tires and Tubes       1.0
# 1  united states  Washington         Clothing           Gloves       2.0
# 2  united states  Washington      Accessories  Tires and Tubes       3.0
# 3  united states  Washington      Accessories  Tires and Tubes       2.0
# 4  united states  Washington      Accessories  Tires and Tubes       3.0
#
#    Unit Cost  Unit Price   Cost  Revenue  Column1 Status
# 0      80.00  109.000000   80.0    109.0      0.0    Low
# ...
